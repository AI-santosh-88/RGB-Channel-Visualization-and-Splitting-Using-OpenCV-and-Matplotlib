# %% [markdown]
# ## Install the packages

# %%
# !pip install opencv-python

# %% [markdown]
# ## Import packages

# %%
import cv2
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## load the image or read the image

# %%
image_cv = cv2.imread('/content/beautiful-bird-img.jpg')
cv2_imshow(image_cv)
# Out:
# <PIL.Image.Image image mode=RGB size=728x546>

# %%
image_cv
# Out:
# array([[[255, 216, 253],
#         [255, 213, 250],
#         [254, 212, 247],
#         ...,
#         [ 46,  51, 106],
#         [ 48,  55, 112],
#         [ 47,  54, 111]],
#
#        [[255, 216, 251],
#         [255, 214, 249],
#         [251, 212, 244],
#         ...,
#         [ 27,  34,  83],
#         [ 39,  51,  99],
#         [ 63,  75, 123]],
#
#        [[255, 216, 248],
#         [253, 214, 246],
#         [249, 213, 243],
#         ...,
#         [ 57,  66, 104],
#         [ 60,  73, 111],
#         [ 87, 100, 138]],
#
#        ...,
#
#        [[239, 181, 229],
#         [239, 181, 229],
#         [239, 181, 229],
#         ...,
#         [231, 164, 226],
#         [231, 164, 226],
#         [231, 164, 226]],
#
#        [[239, 181, 229],
#         [239, 181, 229],
#         [239, 181, 229],
#         ...,
#         [232, 165, 227],
#         [232, 165, 227],
#         [231, 164, 226]],
#
#        [[239, 181, 229],
#         [239, 181, 229],
#         [239, 181, 229],
# ...

# %%
image_cv.shape

# image is a kind of matrix
# rows = 546
# columns = 728
# 3 indicates RGB channel
# Out:
# (546, 728, 3)

# %%
cv2.split(image_cv)
# Out:
# (array([[255, 255, 254, ...,  46,  48,  47],
#         [255, 255, 251, ...,  27,  39,  63],
#         [255, 253, 249, ...,  57,  60,  87],
#         ...,
#         [239, 239, 239, ..., 231, 231, 231],
#         [239, 239, 239, ..., 232, 232, 231],
#         [239, 239, 239, ..., 232, 232, 231]], dtype=uint8),
#  array([[216, 213, 212, ...,  51,  55,  54],
#         [216, 214, 212, ...,  34,  51,  75],
#         [216, 214, 213, ...,  66,  73, 100],
#         ...,
#         [181, 181, 181, ..., 164, 164, 164],
#         [181, 181, 181, ..., 165, 165, 164],
#         [181, 181, 181, ..., 165, 165, 164]], dtype=uint8),
#  array([[253, 250, 247, ..., 106, 112, 111],
#         [251, 249, 244, ...,  83,  99, 123],
#         [248, 246, 243, ..., 104, 111, 138],
#         ...,
#         [229, 229, 229, ..., 226, 226, 226],
#         [229, 229, 229, ..., 227, 227, 226],
#         [229, 229, 229, ..., 227, 227, 226]], dtype=uint8))

# %%
b,g,r = cv2.split(image_cv)

# %%
b
# Out:
# array([[255, 255, 254, ...,  46,  48,  47],
#        [255, 255, 251, ...,  27,  39,  63],
#        [255, 253, 249, ...,  57,  60,  87],
#        ...,
#        [239, 239, 239, ..., 231, 231, 231],
#        [239, 239, 239, ..., 232, 232, 231],
#        [239, 239, 239, ..., 232, 232, 231]], dtype=uint8)

# %%
g
# Out:
# array([[216, 213, 212, ...,  51,  55,  54],
#        [216, 214, 212, ...,  34,  51,  75],
#        [216, 214, 213, ...,  66,  73, 100],
#        ...,
#        [181, 181, 181, ..., 164, 164, 164],
#        [181, 181, 181, ..., 165, 165, 164],
#        [181, 181, 181, ..., 165, 165, 164]], dtype=uint8)

# %%
r
# Out:
# array([[253, 250, 247, ..., 106, 112, 111],
#        [251, 249, 244, ...,  83,  99, 123],
#        [248, 246, 243, ..., 104, 111, 138],
#        ...,
#        [229, 229, 229, ..., 226, 226, 226],
#        [229, 229, 229, ..., 227, 227, 226],
#        [229, 229, 229, ..., 227, 227, 226]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(r,cmap='gray')

# %%
import matplotlib.pyplot as plt
plt.imshow(r,cmap='Reds')

# %%
import matplotlib.pyplot as plt
plt.imshow(r,cmap='Greens')

# %%
import matplotlib.pyplot as plt
plt.imshow(r,cmap = 'Blues')
